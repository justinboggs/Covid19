# %%
import pandas as pd

# %%
data = pd.read_excel('static/data/six-dem.xls')

# %%
data.head()
# Out:
#    ctr      country   pdi   idv   mas   uai     ltowvs        ivr
# 0  AFE  Africa East  64.0  27.0  41.0  52.0  32.000000  40.000000
# 1  AFW  Africa West  77.0  20.0  46.0  54.0   9.000000  78.000000
# 2  ALB      Albania   NaN   NaN   NaN   NaN  61.460957  14.508929
# 3  ALG      Algeria   NaN   NaN   NaN   NaN  25.944584  32.366071
# 4  AND      Andorra   NaN   NaN   NaN   NaN        NaN  65.000000

# %%
data = data.rename(columns = {'ctr':'CTR', 'country':'Country', 'pdi': 'Power Distance Index', 'idv': 'Individualism', \
                           'mas': 'Masculinity', 'uai': 'Uncertainty Avoidiance'})

# %%
data.head()
# Out:
#    CTR      Country  Power Distance Index  Individualism  Masculinity  \
# 0  AFE  Africa East                  64.0           27.0         41.0
# 1  AFW  Africa West                  77.0           20.0         46.0
# 2  ALB      Albania                   NaN            NaN          NaN
# 3  ALG      Algeria                   NaN            NaN          NaN
# 4  AND      Andorra                   NaN            NaN          NaN
#
#    Uncertainty Avoidiance     ltowvs        ivr
# 0                    52.0  32.000000  40.000000
# 1                    54.0   9.000000  78.000000
# 2                     NaN  61.460957  14.508929
# 3                     NaN  25.944584  32.366071
# 4                     NaN        NaN  65.000000

# %%
top = data.sort_values('Individualism', ascending=False)
top.head(10)
# Out:
#      CTR          Country  Power Distance Index  Individualism  Masculinity  \
# 103  USA           U.S.A.                  40.0           91.0         62.0
# 8    AUL        Australia                  38.0           90.0         61.0
# 42   GBR    Great Britain                  35.0           89.0         66.0
# 20   CAN           Canada                  39.0           80.0         52.0
# 46   HUN          Hungary                  46.0           80.0         88.0
# 71   NET      Netherlands                  38.0           80.0         14.0
# 72   NZL      New Zealand                  22.0           79.0         58.0
# 15   BEN  Belgium Netherl                  61.0           78.0         43.0
# 54   ITA            Italy                  50.0           76.0         70.0
# 13   BEL          Belgium                  65.0           75.0         54.0
#
#      Uncertainty Avoidiance     ltowvs        ivr
# 103                    46.0  25.692695  68.080357
# ...

# %%
bottom = data.sort_values('Individualism')
bottom.head(25)
# Out:
#      CTR              Country  Power Distance Index  Individualism  \
# 44   GUA            Guatemala                  95.0            6.0
# 31   ECA              Ecuador                  78.0            8.0
# 76   PAN               Panama                  95.0           11.0
# 107  VEN            Venezuela                  81.0           12.0
# 24   COL             Colombia                  67.0           13.0
# 49   IDO            Indonesia                  78.0           14.0
# 75   PAK             Pakistan                  55.0           14.0
# 25   COS           Costa Rica                  35.0           15.0
# 77   PER                 Peru                  64.0           16.0
# 101  TRI  Trinidad and Tobago                  47.0           16.0
# 98   TAI               Taiwan                  58.0           17.0
# 58   KOR          Korea South                  60.0           18.0
# 34   SAL          El Salvador                  66.0           19.0
# ...

# %%
data.describe()
# Out:
#        Power Distance Index  Individualism  Masculinity  \
# count             78.000000      78.000000    78.000000
# mean              59.333333      45.166667    49.269231
# std               21.223405      23.971529    19.007636
# min               11.000000       6.000000     5.000000
# 25%               42.500000      23.500000    40.000000
# 50%               62.000000      43.500000    48.500000
# 75%               72.500000      67.750000    61.750000
# max              104.000000      91.000000   110.000000
#
#        Uncertainty Avoidiance      ltowvs         ivr
# count               78.000000   96.000000   97.000000
# mean                67.641026   45.479272   45.425534
# std                 22.992926   24.232016   22.174204
# min                  8.000000    0.000000    0.000000
# 25%                 51.250000   25.566751   29.241071
# 50%                 69.500000   44.584383   43.080357
# 75%                 86.000000   63.602015   63.000000
# ...
