# %%
#import dependencies
import pandas as pd

# %%
# read in the csv file
covid_data = pd.read_csv('merged_data_modified.csv')

# %%
covid_data.head()
# Out:
#    Unnamed: 0   Entity Code  pop_density           gdp  total_pop  urban_pop  \
# 0           0  Albania  ALB   105.135146  10970.452245  2923352.0    1654503
# 1           1  Albania  ALB   105.135146  10970.452245  2923352.0    1654503
# 2           2  Albania  ALB   105.135146  10970.452245  2923352.0    1654503
# 3           3  Albania  ALB   105.135146  10970.452245  2923352.0    1654503
# 4           4  Albania  ALB   105.135146  10970.452245  2923352.0    1654503
#
#    rural_pop  urban_pct  rural_pct  ...  median_age  pdi idv mas uai ltowvs  \
# 0    1226200     57.434  42.566002  ...   36.200001   90  20  80  70     61
# 1    1226200     57.434  42.566002  ...   36.200001   90  20  80  70     61
# 2    1226200     57.434  42.566002  ...   36.200001   90  20  80  70     61
# 3    1226200     57.434  42.566002  ...   36.200001   90  20  80  70     61
# 4    1226200     57.434  42.566002  ...   36.200001   90  20  80  70     61
#
#   ivr       Date cases  days_gt_100
# ...

# %%
#export to html file
covid_data.to_html('covid_data_html.html')
